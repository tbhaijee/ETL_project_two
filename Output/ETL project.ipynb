# %%
import pandas as pd
import os
path = "clean_edsatdata.csv"
df = pd.read_csv(path)
df
# Out:
#              Country Name       1985       1986      1987      1988  \
# 0                 Albania   7.026240   7.221590   7.32742   7.73881
# 1               Argentina  35.646099  37.512169  39.27063       NaN
# 2               Australia  27.785280  29.354740  29.49725  31.27887
# 3                 Austria  25.560610  26.740040  27.85111  29.40321
# 4            Bahamas, The  15.004160  17.453779  19.36624  20.94272
# ..                    ...        ...        ...       ...       ...
# 111  United Arab Emirates        NaN        NaN       NaN       NaN
# 112        United Kingdom        NaN        NaN       NaN       NaN
# 113         United States        NaN        NaN       NaN       NaN
# 114         Venezuela, RB        NaN        NaN       NaN       NaN
# 115              Zimbabwe        NaN        NaN       NaN       NaN
#
#           1989       1990       1991       1992       1993  ...       1995  \
# ...

# %%
df = df.melt(id_vars=["Country Name"], 
        var_name="Year", 
        value_name="Value")
df
# Out:
#               Country Name  Year      Value
# 0                  Albania  1985   7.026240
# 1                Argentina  1985  35.646099
# 2                Australia  1985  27.785280
# 3                  Austria  1985  25.560610
# 4             Bahamas, The  1985  15.004160
# ...                    ...   ...        ...
# 2315  United Arab Emirates  2004        NaN
# 2316        United Kingdom  2004        NaN
# 2317         United States  2004        NaN
# 2318         Venezuela, RB  2004        NaN
# 2319              Zimbabwe  2004        NaN
#
# [2320 rows x 3 columns]

# %%
df.to_csv('literacydata.csv')

# %%
path = "master.csv"
m = pd.read_csv(path)
m
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
m = m[['country','year','sex','age','suicides_no']]
m
# Out:
#           country  year     sex          age  suicides_no
# 0         Albania  1987    male  15-24 years           21
# 1         Albania  1987    male  35-54 years           16
# 2         Albania  1987  female  15-24 years           14
# 3         Albania  1987    male    75+ years            1
# 4         Albania  1987    male  25-34 years            9
# ...           ...   ...     ...          ...          ...
# 27815  Uzbekistan  2014  female  35-54 years          107
# 27816  Uzbekistan  2014  female    75+ years            9
# 27817  Uzbekistan  2014    male   5-14 years           60
# 27818  Uzbekistan  2014  female   5-14 years           44
# 27819  Uzbekistan  2014  female  55-74 years           21
#
# [27820 rows x 5 columns]

# %%
m.to_csv("master.csv")

# %%
country = m['country'].unique()
country
# Out:
# array(['Albania', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Barbados', 'Belarus', 'Belgium', 'Belize',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Cabo Verde',
#        'Canada', 'Chile', 'Colombia', 'Costa Rica', 'Croatia', 'Cuba',
#        'Cyprus', 'Czech Republic', 'Denmark', 'Dominica', 'Ecuador',
#        'El Salvador', 'Estonia', 'Fiji', 'Finland', 'France', 'Georgia',
#        'Germany', 'Greece', 'Grenada', 'Guatemala', 'Guyana', 'Hungary',
#        'Iceland', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kiribati', 'Kuwait', 'Kyrgyzstan', 'Latvia',
#        'Lithuania', 'Luxembourg', 'Macau', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Netherlands',
#        'New Zealand', 'Nicaragua', 'Norway', 'Oman', 'Panama', 'Paraguay',
#        'Philippines', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
# ...

# %%
len(country)
# Out:
# 101

# %%
country_df = pd.DataFrame()

# %%
country_df['countryname']= country
country_df.to_csv("country.csv")

# %%
sex = m['sex'].unique()
sex
# Out:
# array(['male', 'female'], dtype=object)

# %%
year = m['year'].unique()
year
# Out:
# array([1987, 1988, 1989, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        1985, 1986, 1990, 1991, 2012, 2013, 2014, 2015, 2011, 2016],
#       dtype=int64)

# %%
len(year)
# Out:
# 32

# %%
age = m['age'].unique()
age
# Out:
# array(['15-24 years', '35-54 years', '75+ years', '25-34 years',
#        '55-74 years', '5-14 years'], dtype=object)

# %%
len(age)
# Out:
# 6
